# %% [markdown]
# Игра угадай число

# %%
from game1 import game_core_v2
from game1 import score_game

# %% [markdown]
# Угадываем число

# %%
score_game(game_core_v2)
# Out:
# Компьютер вычислил число с 6-ой попытки
# Компьютер вычислил число с 6-ой попытки
# Компьютер вычислил число с 5-ой попытки
# Компьютер вычислил число с 6-ой попытки
# Компьютер вычислил число с 5-ой попытки
# Компьютер вычислил число с 5-ой попытки
# Компьютер вычислил число с 5-ой попытки
# Компьютер вычислил число с 3-ой попытки
# Компьютер вычислил число с 5-ой попытки
# Компьютер вычислил число с 4-ой попытки
# Компьютер вычислил число с 7-ой попытки
# Компьютер вычислил число с 6-ой попытки
# Компьютер вычислил число с 7-ой попытки
# Компьютер вычислил число с 6-ой попытки
# Компьютер вычислил число с 5-ой попытки
# Компьютер вычислил число с 6-ой попытки
# Компьютер вычислил число с 6-ой попытки
# Компьютер вычислил число с 5-ой попытки
# Компьютер вычислил число с 7-ой попытки
# Компьютер вычислил число с 5-ой попытки
# Компьютер вычислил число с 6-ой попытки
# Компьютер вычислил число с 7-ой попытки
# Компьютер вычислил число с 4-ой попытки
# ...
